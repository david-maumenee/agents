# %% [markdown]
# # 02 Token
#
# ## Tokenizing with code

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("Hi my name is David and I like sailing, bonjour j'aime la voile.")

# %%
tokens

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")

# %%
# English and french longest word
tokens = encoding.encode("pneumonoultramicroscopicsilicovolcanoconiosis anticonstitutionnellement")

# %%
encoding.decode([1001])

# %% [markdown]
# ## To recap
#
# - Everythings is turn into token
